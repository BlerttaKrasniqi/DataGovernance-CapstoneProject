-- %%
CREATE SCHEMA IF NOT EXISTS workspace.bronze;

CREATE SCHEMA IF NOT EXISTS workspace.silver;

CREATE SCHEMA IF NOT EXISTS workspace.gold;

-- %%
SHOW TABLES IN workspace.default;

-- %%
CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_customers AS
SELECT * FROM workspace.default.bronze_customers;

CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_orders AS
SELECT * FROM workspace.default.bronze_orders;

CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_products AS
SELECT * FROM workspace.default.bronze_products;

CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_payments AS
SELECT * FROM workspace.default.bronze_payments;

CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_billing_transactions AS
SELECT * FROM workspace.default.bronze_billing_transactions;

CREATE TABLE IF NOT EXISTS workspace.bronze.bronze_metadata AS
SELECT * FROM workspace.default.bronze_metadata;

-- %%
SHOW TABLES IN workspace.bronze;

-- %%
CREATE TABLE IF NOT EXISTS workspace.silver.silver_customers AS
SELECT * FROM workspace.default.silver_customers;

CREATE TABLE IF NOT EXISTS workspace.silver.silver_orders AS
SELECT * FROM workspace.default.silver_orders;

CREATE TABLE IF NOT EXISTS workspace.silver.silver_products AS
SELECT * FROM workspace.default.silver_products;

CREATE TABLE IF NOT EXISTS workspace.silver.silver_payments AS
SELECT * FROM workspace.default.silver_payments;

CREATE TABLE IF NOT EXISTS workspace.silver.silver_billing_transactions AS
SELECT * FROM workspace.default.silver_billing_transactions;

CREATE TABLE IF NOT EXISTS workspace.silver.silver_metadata AS
SELECT * FROM workspace.default.silver_metadata;

-- %%
SHOW TABLES IN workspace.silver;
