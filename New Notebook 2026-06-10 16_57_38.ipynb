# %%
import pandas as pd

# Paste the complete Blob SAS URL you copied from Azure inside the quotes
sas_url = "https://datagov2026.blob.core.windows.net/governed-landing-zone/metadata_realistic_10k%201(in).csv?sp=r&st=2026-06-10T14:56:09Z&se=2026-06-10T23:11:09Z&spr=https&sv=2026-02-06&sr=b&sig=B8N2u2vIas%2Bp79mT3DGwJueJBWAWzY%2BrYo5FuaVdjzU%3D"

# Read the file via HTTP using Pandas to bypass serverless restrictions
pandas_df = pd.read_csv(sas_url)

# Convert the data into a standard Spark DataFrame for your assignment
df = spark.createDataFrame(pandas_df)

# View your dataset
display(df)
