# %%
import pandas as pd

sas_url = "https://datagov2026.blob.core.windows.net/governed-landing-zone/metadata_realistic_10k%201(in).csv?sp=r&st=2026-06-11T09:41:43Z&se=2026-07-11T17:56:43Z&spr=https&sv=2026-02-06&sr=b&sig=OpeQ2Y%2Bzt3gYCMtPG4t8oxEBg8FEr2IsUQ5oNDI4j6c%3D"

pandas_df = pd.read_csv(sas_url)

df = spark.createDataFrame(pandas_df)

display(df)
df.write.mode("overwrite").saveAsTable("table_metadata")

# %%
df.printSchema()

# %%
print(df.columns)

# %%
metadata_df = df.select(
    "column_id",
    "column_name",
    "column_desc",
    "term_name",
    "term_description",
    "security_classification",
    "critical_data_element_flag",
    "pii_flag",
    "term_subdomain",
    "data_steward",
    "table_id",
    "table_name",
    "table_desc",
    "table_owner_in_source",
    "schema_id",
    "schema_name",
    "database_id",
    "database_name",
    "system_id",
    "system_name",
    "location",
    "total_record_count",
    "invalid_record_count",
    "tag_name",
    "tag_value",
    "certification_level"
)

display(metadata_df)
metadata_df.write.mode("overwrite").saveAsTable("column_metadata")
